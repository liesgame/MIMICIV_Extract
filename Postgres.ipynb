# %%
from os.path import isfile, isdir, splitext
import argparse
import pickle as cPickle
import numpy.random as npr
from heuristic_sentence_splitter import sent_tokenize_rules
from mimic_querier import *

# %%
args = {}
args['psql_host'] = 'localhost'
args['psql_dbname'] = 'mimiciv'
args['psql_schema_name'] = 'mimiciv_derived, mimiciv_hosp, mimiciv_icu, mimiciv_ed'
args['psql_user'] = 'postgres'
args['psql_password'] = 'root'
dbname = args['psql_dbname']
schema_name = args['psql_schema_name']
query_args = {'dbname': dbname}
if args['psql_host'] is not None: 
    query_args['host'] = args['psql_host']
if args['psql_user'] is not None: 
    query_args['user'] = args['psql_user']
if args['psql_password'] is not None: 
    query_args['password'] = args['psql_password']

# %%
querier = MIMIC_Querier(query_args=query_args, schema_name=schema_name)
querier.connect()

# %%
stay_id_count = pd.read_sql_query('select count(distinct stay_id) from mimiciv_derived.icustay_detail ',querier.connection ).iloc[0][0]

# %%
stay_id_count
# Out:
# 73181

# %%
query = '''
with
t1 as (select itemid, chartevents.stay_id from mimiciv_icu.chartevents  inner join mimiciv_derived.icustay_detail on icustay_detail.stay_id = chartevents.stay_id
where chartevents.charttime between icustay_detail.icu_intime and icu_outtime
group by itemid, chartevents.stay_id)
, t2 as (select itemid, count(*) as count from t1 group by itemid order by count desc)
select t2.count, d_items.* from t2 inner join mimiciv_icu.d_items on t2.itemid = d_items.itemid order by count desc ;
'''
charevent_with_txt = pd.read_sql_query(query,querier.connection )

# %%
charevent_with_txt.insert(1,'percentage',charevent_with_txt['count'] / stay_id_count)

# %%
charevent_with_txt
# Out:
#       count  percentage  itemid                                    label  \
# 0     73163    0.999754  220045                               Heart Rate
# 1     73083    0.998661  220210                         Respiratory Rate
# 2     73069    0.998470  220277              O2 saturation pulseoxymetry
# 3     72755    0.994179  220048                             Heart Rhythm
# 4     72640    0.992607  220739                        GCS - Eye Opening
# 5     72629    0.992457  223900                    GCS - Verbal Response
# 6     72618    0.992307  223901                     GCS - Motor Response
# 7     72586    0.991869  224641                                Alarms On
# 8     72558    0.991487  224080                              Head of Bed
# 9     72476    0.990366  224082                                     Turn
# 10    72438    0.989847  224642                         Temperature Site
# 11    72435    0.989806  223986                          RUL Lung Sounds
# 12    72431    0.989751  223988                          LUL Lung Sounds
# 13    72413    0.989505  223987                          RLL Lung Sounds
# 14    72410    0.989464  224168                       Parameters Checked
# 15    72407    0.989423  223989                          LLL Lung Sounds
# 16    72336    0.988453  224003                     Abdominal Assessment
# 17    72283    0.987729  224026                           Skin Integrity
# 18    72268    0.987524  224086                       Activity Tolerance
# 19    72262    0.987442  223781                             Pain Present
# 20    72259    0.987401  223999                              Oral Cavity
# 21    72251    0.987292  224027                         Skin Temperature
# 22    72240    0.987141  224860                           Skin Condition
# 23    72223    0.986909  220047                   Heart Rate Alarm - Low
# 24    72220    0.986868  220046                  Heart rate Alarm - High
# 25    72209    0.986718  220181         Non Invasive Blood Pressure mean
# 26    72208    0.986704  224004                             Bowel Sounds
# 27    72202    0.986622  220179     Non Invasive Blood Pressure systolic
# 28    72201    0.986609  223770  O2 Saturation Pulseoxymetry Alarm - Low
# 29    72198    0.986568  220180    Non Invasive Blood Pressure diastolic
# ...     ...         ...     ...                                      ...
# 2197      1    0.000014  225657                           Freeform Coags
# 2198      1    0.000014  229875                  Oxygenator visible (CH)
# 2199      1    0.000014  229876        Pump plugged into RED outlet (CH)
# 2200      1    0.000014  229564                        Plan-Abdominal/GI
# 2201      1    0.000014  229036                  Incision Appearance #10
# 2202      1    0.000014  229031                  Incision #10- Treatment
# 2203      1    0.000014  224745                     Respiratory Quotient
# 2204      1    0.000014  229052             Incision Drainage Amount #10
# 2205      1    0.000014  227458                                   Procan
# 2206      1    0.000014  224727               Resting Energy Expenditure
# 2207      1    0.000014  227459                              Procan Napa
# 2208      1    0.000014  227774                     Traction/Immobile #4
# 2209      1    0.000014  229571                      Plan-MSK/Skin/Wound
# 2210      1    0.000014  229635               Applied Cognitive (AM-PAC)
# 2211      1    0.000014  224454            Traction/Immobile Location #4
# 2212      1    0.000014  228119  Depth at which wedge obtained (PA Line)
# 2213      1    0.000014  227777            Skeletal Traction #3 - Pounds
# 2214      1    0.000014  224450                     Traction/Immobile #3
# 2215      1    0.000014  229040            Incision #10- Dressing Status
# 2216      1    0.000014  229879    Cannula sites visually inspected (CH)
# 2217      1    0.000014  227039                             PO2_ApacheIV
# 2218      1    0.000014  227122                     Neuro Drain Landmark
# 2219      1    0.000014  225656                       Freeform Chemistry
# 2220      1    0.000014  228619                Pressure Ulcer #10- Depth
# 2221      1    0.000014  229044                     Incision Closure #10
# 2222      1    0.000014  228326                 PC Sacrament of the Sick
# 2223      1    0.000014  223059                     Intubation - Details
# 2224      1    0.000014  228703                          Musculoskeletal
# 2225      1    0.000014  229878          Circuit inspected for clot (CH)
# 2226      1    0.000014  228708                                    Renal
#
#                                  abbreviation      linksto  \
# 0                                          HR  chartevents
# 1                                          RR  chartevents
# 2                                        SpO2  chartevents
# 3                                Heart Rhythm  chartevents
# 4                                 Eye Opening  chartevents
# 5                             Verbal Response  chartevents
# 6                              Motor Response  chartevents
# 7                                   Alarms On  chartevents
# 8                                         HOB  chartevents
# 9                                        Turn  chartevents
# 10                                  Temp Site  chartevents
# 11                            RUL Lung Sounds  chartevents
# 12                            LUL Lung Sounds  chartevents
# 13                            RLL Lung Sounds  chartevents
# 14                         Parameters Checked  chartevents
# 15                            LLL Lung Sounds  chartevents
# 16                       Abdominal Assessment  chartevents
# 17                             Skin Integrity  chartevents
# 18                         Activity Tolerance  chartevents
# 19                               Pain Present  chartevents
# 20                                Oral Cavity  chartevents
# 21                                  Skin Temp  chartevents
# 22                             Skin Condition  chartevents
# 23                             HR Alarm - Low  chartevents
# 24                            HR Alarm - High  chartevents
# 25                                       NBPm  chartevents
# 26                               Bowel Sounds  chartevents
# 27                                       NBPs  chartevents
# 28                           SpO2 Alarm - Low  chartevents
# 29                                       NBPd  chartevents
# ...                                       ...          ...
# 2197                           Freeform Coags  chartevents
# 2198                  Oxygenator visible (CH)  chartevents
# 2199        Pump plugged into RED outlet (CH)  chartevents
# 2200                        Plan-Abdominal/GI  chartevents
# 2201                  Incision Appearance #10  chartevents
# 2202                  Incision #10- Treatment  chartevents
# 2203                                       RQ  chartevents
# 2204             Incision Drainage Amount #10  chartevents
# 2205                                   Procan  chartevents
# 2206                                      REE  chartevents
# 2207                              Procan Napa  chartevents
# 2208                     Traction/Immobile #4  chartevents
# 2209                      Plan-MSK/Skin/Wound  chartevents
# 2210               Applied Cognitive (AM-PAC)  chartevents
# 2211            Traction/Immobile Location #4  chartevents
# 2212  Depth at which wedge obtained (PA Line)  chartevents
# 2213            Skeletal Traction #3 - Pounds  chartevents
# 2214                     Traction/Immobile #3  chartevents
# 2215            Incision #10- Dressing Status  chartevents
# 2216    Cannula sites visually inspected (CH)  chartevents
# 2217                             PO2_ApacheIV  chartevents
# 2218                     Neuro Drain Landmark  chartevents
# 2219                       Freeform Chemistry  chartevents
# 2220                Pressure Ulcer #10- Depth  chartevents
# 2221                     Incision Closure #10  chartevents
# 2222                 PC Sacrament of the Sick  chartevents
# 2223                     Intubation - Details  chartevents
# 2224                          Musculoskeletal  chartevents
# 2225          Circuit inspected for clot (CH)  chartevents
# 2226                                    Renal  chartevents
#
#                     category  unitname        param_type  lownormalvalue  \
# 0        Routine Vital Signs       bpm           Numeric             NaN
# 1                Respiratory  insp/min           Numeric             NaN
# 2                Respiratory         %           Numeric             NaN
# 3        Routine Vital Signs      None              Text             NaN
# 4               Neurological      None              Text             NaN
# 5               Neurological      None              Text             NaN
# 6               Neurological      None              Text             NaN
# 7                     Alarms      None          Checkbox             NaN
# 8                 Treatments      None              Text             NaN
# 9                 Treatments      None              Text             NaN
# 10       Routine Vital Signs      None              Text             NaN
# 11                 Pulmonary      None              Text             NaN
# 12                 Pulmonary      None              Text             NaN
# 13                 Pulmonary      None              Text             NaN
# 14                    Alarms      None          Checkbox             NaN
# 15                 Pulmonary      None              Text             NaN
# 16                     GI/GU      None              Text             NaN
# 17         Skin - Assessment      None              Text             NaN
# 18                Treatments      None              Text             NaN
# 19             Pain/Sedation      None              Text             NaN
# 20                     GI/GU      None              Text             NaN
# 21         Skin - Assessment      None              Text             NaN
# 22         Skin - Assessment      None              Text             NaN
# 23                    Alarms       bpm           Numeric             NaN
# 24                    Alarms       bpm           Numeric             NaN
# 25       Routine Vital Signs      mmHg           Numeric             NaN
# 26                     GI/GU      None              Text             NaN
# 27       Routine Vital Signs      mmHg           Numeric             NaN
# 28                    Alarms         %           Numeric             NaN
# 29       Routine Vital Signs      mmHg           Numeric             NaN
# ...                      ...       ...               ...             ...
# 2197                    Labs      None           Numeric             NaN
# 2198                    ECMO      None              Text             NaN
# 2199                    ECMO      None              Text             NaN
# 2200        MD Progress Note      None              Text             NaN
# 2201        Skin - Incisions      None              Text             NaN
# 2202        Skin - Incisions      None              Text             NaN
# 2203             Respiratory      None           Numeric             NaN
# 2204        Skin - Incisions      None              Text             NaN
# 2205                    Labs      None  Numeric with tag             NaN
# 2206             Respiratory  kcal/day           Numeric             NaN
# 2207                    Labs      None  Numeric with tag             NaN
# 2208              Treatments      None              Text             NaN
# 2209        MD Progress Note      None              Text             NaN
# 2210              Treatments      None              Text             NaN
# 2211              Treatments      None              Text             NaN
# 2212       PA Line Insertion        cm           Numeric             NaN
# 2213              Treatments       lbs           Numeric             NaN
# 2214              Treatments      None              Text             NaN
# 2215        Skin - Incisions      None              Text             NaN
# 2216                    ECMO      None              Text             NaN
# 2217  Scores - APACHE IV (2)      mmHg           Numeric             NaN
# 2218            Neurological      None              Text             NaN
# 2219                    Labs      None           Numeric             NaN
# 2220       Skin - Impairment        cm           Numeric             NaN
# 2221        Skin - Incisions      None              Text             NaN
# 2222      Pastoral Care Note      None              Text             NaN
# 2223             Respiratory      None              Text             NaN
# 2224        MD Progress Note      None              Text             NaN
# 2225                    ECMO      None              Text             NaN
# 2226        MD Progress Note      None              Text             NaN
#
#       highnormalvalue
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 2197              NaN
# 2198              NaN
# 2199              NaN
# 2200              NaN
# 2201              NaN
# 2202              NaN
# 2203              NaN
# 2204              NaN
# 2205              NaN
# 2206              NaN
# 2207              NaN
# 2208              NaN
# 2209              NaN
# 2210              NaN
# 2211              NaN
# 2212              NaN
# 2213              NaN
# 2214              NaN
# 2215              NaN
# 2216              NaN
# 2217              NaN
# 2218              NaN
# 2219              NaN
# 2220              NaN
# 2221              NaN
# 2222              NaN
# 2223              NaN
# 2224              NaN
# 2225              NaN
# 2226              NaN
#
# [2227 rows x 11 columns]

# %%
charevent_with_txt.loc[charevent_with_txt['param_type'] == 'Numeric'].to_csv('charevent.csv', index = False)

# %%
charevent_with_txt.to_csv('charevent_with_txt.csv', index = False)

# %%
query = '''
with t1 as (select itemid, chartevents.stay_id, chartevents.value from mimiciv_icu.chartevents  inner join mimiciv_derived.icustay_detail on icustay_detail.stay_id = chartevents.stay_id
where chartevents.charttime between icustay_detail.icu_intime and icu_outtime),
t2 as (select * from mimiciv_icu.d_items where linksto = 'chartevents' and param_type = 'Text'),
t3 as (select t1.stay_id, t1.itemid, t1.value from t1 inner join t2 on t1.itemid = t2.itemid)
select itemid, count(distinct value) as type from t3 group by itemid order by type desc;

'''
labevent_txt_distanct = pd.read_sql_query(query,querier.connection )

# %%
labevent_txt_distanct
# Out:
#       itemid  type
# 0     220001  1045
# 1     228497    95
# 2     228496    95
# 3     228499    95
# 4     228498    95
# 5     228559    94
# 6     228500    92
# 7     228560    92
# 8     228506    89
# 9     228561    87
# 10    228501    86
# 11    224032    84
# 12    228508    83
# 13    224930    83
# 14    228507    82
# 15    224931    82
# 16    224933    82
# 17    224932    81
# 18    228502    80
# 19    224934    78
# 20    224935    77
# 21    224936    71
# 22    228503    68
# 23    228562    67
# 24    228510    66
# 25    228509    63
# 26    227606    59
# 27    228563    56
# 28    228504    52
# 29    227607    51
# ...      ...   ...
# 1379  225954     1
# 1380  228852     1
# 1381  228842     1
# 1382  227122     1
# 1383  229562     1
# 1384  228326     1
# 1385  229840     1
# 1386  228550     1
# 1387  228708     1
# 1388  228558     1
# 1389  228557     1
# 1390  229552     1
# 1391  228556     1
# 1392  229564     1
# 1393  229566     1
# 1394  229879     1
# 1395  229567     1
# 1396  228549     1
# 1397  229878     1
# 1398  229876     1
# 1399  229875     1
# 1400  229558     1
# 1401  229052     1
# 1402  229635     1
# 1403  229874     1
# 1404  224454     1
# 1405  229873     1
# 1406  228555     1
# 1407  225741     1
# 1408  227774     1
#
# [1409 rows x 2 columns]

# %%
charevent_txt_distanct = charevent_with_txt.set_index('itemid').join(labevent_txt_distanct.set_index('itemid')).reset_index()

# %%
charevent_txt_distanct
# Out:
#       itemid  count  percentage                                    label  \
# 0     220045  73163    0.999754                               Heart Rate
# 1     220210  73083    0.998661                         Respiratory Rate
# 2     220277  73069    0.998470              O2 saturation pulseoxymetry
# 3     220048  72755    0.994179                             Heart Rhythm
# 4     220739  72640    0.992607                        GCS - Eye Opening
# 5     223900  72629    0.992457                    GCS - Verbal Response
# 6     223901  72618    0.992307                     GCS - Motor Response
# 7     224641  72586    0.991869                                Alarms On
# 8     224080  72558    0.991487                              Head of Bed
# 9     224082  72476    0.990366                                     Turn
# 10    224642  72438    0.989847                         Temperature Site
# 11    223986  72435    0.989806                          RUL Lung Sounds
# 12    223988  72431    0.989751                          LUL Lung Sounds
# 13    223987  72413    0.989505                          RLL Lung Sounds
# 14    224168  72410    0.989464                       Parameters Checked
# 15    223989  72407    0.989423                          LLL Lung Sounds
# 16    224003  72336    0.988453                     Abdominal Assessment
# 17    224026  72283    0.987729                           Skin Integrity
# 18    224086  72268    0.987524                       Activity Tolerance
# 19    223781  72262    0.987442                             Pain Present
# 20    223999  72259    0.987401                              Oral Cavity
# 21    224027  72251    0.987292                         Skin Temperature
# 22    224860  72240    0.987141                           Skin Condition
# 23    220047  72223    0.986909                   Heart Rate Alarm - Low
# 24    220046  72220    0.986868                  Heart rate Alarm - High
# 25    220181  72209    0.986718         Non Invasive Blood Pressure mean
# 26    224004  72208    0.986704                             Bowel Sounds
# 27    220179  72202    0.986622     Non Invasive Blood Pressure systolic
# 28    223770  72201    0.986609  O2 Saturation Pulseoxymetry Alarm - Low
# 29    220180  72198    0.986568    Non Invasive Blood Pressure diastolic
# ...      ...    ...         ...                                      ...
# 2197  225657      1    0.000014                           Freeform Coags
# 2198  229875      1    0.000014                  Oxygenator visible (CH)
# 2199  229876      1    0.000014        Pump plugged into RED outlet (CH)
# 2200  229564      1    0.000014                        Plan-Abdominal/GI
# 2201  229036      1    0.000014                  Incision Appearance #10
# 2202  229031      1    0.000014                  Incision #10- Treatment
# 2203  224745      1    0.000014                     Respiratory Quotient
# 2204  229052      1    0.000014             Incision Drainage Amount #10
# 2205  227458      1    0.000014                                   Procan
# 2206  224727      1    0.000014               Resting Energy Expenditure
# 2207  227459      1    0.000014                              Procan Napa
# 2208  227774      1    0.000014                     Traction/Immobile #4
# 2209  229571      1    0.000014                      Plan-MSK/Skin/Wound
# 2210  229635      1    0.000014               Applied Cognitive (AM-PAC)
# 2211  224454      1    0.000014            Traction/Immobile Location #4
# 2212  228119      1    0.000014  Depth at which wedge obtained (PA Line)
# 2213  227777      1    0.000014            Skeletal Traction #3 - Pounds
# 2214  224450      1    0.000014                     Traction/Immobile #3
# 2215  229040      1    0.000014            Incision #10- Dressing Status
# 2216  229879      1    0.000014    Cannula sites visually inspected (CH)
# 2217  227039      1    0.000014                             PO2_ApacheIV
# 2218  227122      1    0.000014                     Neuro Drain Landmark
# 2219  225656      1    0.000014                       Freeform Chemistry
# 2220  228619      1    0.000014                Pressure Ulcer #10- Depth
# 2221  229044      1    0.000014                     Incision Closure #10
# 2222  228326      1    0.000014                 PC Sacrament of the Sick
# 2223  223059      1    0.000014                     Intubation - Details
# 2224  228703      1    0.000014                          Musculoskeletal
# 2225  229878      1    0.000014          Circuit inspected for clot (CH)
# 2226  228708      1    0.000014                                    Renal
#
#                                  abbreviation      linksto  \
# 0                                          HR  chartevents
# 1                                          RR  chartevents
# 2                                        SpO2  chartevents
# 3                                Heart Rhythm  chartevents
# 4                                 Eye Opening  chartevents
# 5                             Verbal Response  chartevents
# 6                              Motor Response  chartevents
# 7                                   Alarms On  chartevents
# 8                                         HOB  chartevents
# 9                                        Turn  chartevents
# 10                                  Temp Site  chartevents
# 11                            RUL Lung Sounds  chartevents
# 12                            LUL Lung Sounds  chartevents
# 13                            RLL Lung Sounds  chartevents
# 14                         Parameters Checked  chartevents
# 15                            LLL Lung Sounds  chartevents
# 16                       Abdominal Assessment  chartevents
# 17                             Skin Integrity  chartevents
# 18                         Activity Tolerance  chartevents
# 19                               Pain Present  chartevents
# 20                                Oral Cavity  chartevents
# 21                                  Skin Temp  chartevents
# 22                             Skin Condition  chartevents
# 23                             HR Alarm - Low  chartevents
# 24                            HR Alarm - High  chartevents
# 25                                       NBPm  chartevents
# 26                               Bowel Sounds  chartevents
# 27                                       NBPs  chartevents
# 28                           SpO2 Alarm - Low  chartevents
# 29                                       NBPd  chartevents
# ...                                       ...          ...
# 2197                           Freeform Coags  chartevents
# 2198                  Oxygenator visible (CH)  chartevents
# 2199        Pump plugged into RED outlet (CH)  chartevents
# 2200                        Plan-Abdominal/GI  chartevents
# 2201                  Incision Appearance #10  chartevents
# 2202                  Incision #10- Treatment  chartevents
# 2203                                       RQ  chartevents
# 2204             Incision Drainage Amount #10  chartevents
# 2205                                   Procan  chartevents
# 2206                                      REE  chartevents
# 2207                              Procan Napa  chartevents
# 2208                     Traction/Immobile #4  chartevents
# 2209                      Plan-MSK/Skin/Wound  chartevents
# 2210               Applied Cognitive (AM-PAC)  chartevents
# 2211            Traction/Immobile Location #4  chartevents
# 2212  Depth at which wedge obtained (PA Line)  chartevents
# 2213            Skeletal Traction #3 - Pounds  chartevents
# 2214                     Traction/Immobile #3  chartevents
# 2215            Incision #10- Dressing Status  chartevents
# 2216    Cannula sites visually inspected (CH)  chartevents
# 2217                             PO2_ApacheIV  chartevents
# 2218                     Neuro Drain Landmark  chartevents
# 2219                       Freeform Chemistry  chartevents
# 2220                Pressure Ulcer #10- Depth  chartevents
# 2221                     Incision Closure #10  chartevents
# 2222                 PC Sacrament of the Sick  chartevents
# 2223                     Intubation - Details  chartevents
# 2224                          Musculoskeletal  chartevents
# 2225          Circuit inspected for clot (CH)  chartevents
# 2226                                    Renal  chartevents
#
#                     category  unitname        param_type  lownormalvalue  \
# 0        Routine Vital Signs       bpm           Numeric             NaN
# 1                Respiratory  insp/min           Numeric             NaN
# 2                Respiratory         %           Numeric             NaN
# 3        Routine Vital Signs      None              Text             NaN
# 4               Neurological      None              Text             NaN
# 5               Neurological      None              Text             NaN
# 6               Neurological      None              Text             NaN
# 7                     Alarms      None          Checkbox             NaN
# 8                 Treatments      None              Text             NaN
# 9                 Treatments      None              Text             NaN
# 10       Routine Vital Signs      None              Text             NaN
# 11                 Pulmonary      None              Text             NaN
# 12                 Pulmonary      None              Text             NaN
# 13                 Pulmonary      None              Text             NaN
# 14                    Alarms      None          Checkbox             NaN
# 15                 Pulmonary      None              Text             NaN
# 16                     GI/GU      None              Text             NaN
# 17         Skin - Assessment      None              Text             NaN
# 18                Treatments      None              Text             NaN
# 19             Pain/Sedation      None              Text             NaN
# 20                     GI/GU      None              Text             NaN
# 21         Skin - Assessment      None              Text             NaN
# 22         Skin - Assessment      None              Text             NaN
# 23                    Alarms       bpm           Numeric             NaN
# 24                    Alarms       bpm           Numeric             NaN
# 25       Routine Vital Signs      mmHg           Numeric             NaN
# 26                     GI/GU      None              Text             NaN
# 27       Routine Vital Signs      mmHg           Numeric             NaN
# 28                    Alarms         %           Numeric             NaN
# 29       Routine Vital Signs      mmHg           Numeric             NaN
# ...                      ...       ...               ...             ...
# 2197                    Labs      None           Numeric             NaN
# 2198                    ECMO      None              Text             NaN
# 2199                    ECMO      None              Text             NaN
# 2200        MD Progress Note      None              Text             NaN
# 2201        Skin - Incisions      None              Text             NaN
# 2202        Skin - Incisions      None              Text             NaN
# 2203             Respiratory      None           Numeric             NaN
# 2204        Skin - Incisions      None              Text             NaN
# 2205                    Labs      None  Numeric with tag             NaN
# 2206             Respiratory  kcal/day           Numeric             NaN
# 2207                    Labs      None  Numeric with tag             NaN
# 2208              Treatments      None              Text             NaN
# 2209        MD Progress Note      None              Text             NaN
# 2210              Treatments      None              Text             NaN
# 2211              Treatments      None              Text             NaN
# 2212       PA Line Insertion        cm           Numeric             NaN
# 2213              Treatments       lbs           Numeric             NaN
# 2214              Treatments      None              Text             NaN
# 2215        Skin - Incisions      None              Text             NaN
# 2216                    ECMO      None              Text             NaN
# 2217  Scores - APACHE IV (2)      mmHg           Numeric             NaN
# 2218            Neurological      None              Text             NaN
# 2219                    Labs      None           Numeric             NaN
# 2220       Skin - Impairment        cm           Numeric             NaN
# 2221        Skin - Incisions      None              Text             NaN
# 2222      Pastoral Care Note      None              Text             NaN
# 2223             Respiratory      None              Text             NaN
# 2224        MD Progress Note      None              Text             NaN
# 2225                    ECMO      None              Text             NaN
# 2226        MD Progress Note      None              Text             NaN
#
#       highnormalvalue  type
# 0                 NaN   NaN
# 1                 NaN   NaN
# 2                 NaN   NaN
# 3                 NaN  26.0
# 4                 NaN   4.0
# 5                 NaN   6.0
# 6                 NaN   6.0
# 7                 NaN   NaN
# 8                 NaN   8.0
# 9                 NaN   9.0
# 10                NaN   7.0
# 11                NaN  13.0
# 12                NaN  13.0
# 13                NaN  13.0
# 14                NaN   NaN
# 15                NaN  13.0
# 16                NaN  11.0
# 17                NaN   2.0
# 18                NaN   4.0
# 19                NaN   2.0
# 20                NaN  10.0
# 21                NaN   4.0
# 22                NaN   5.0
# 23                NaN   NaN
# 24                NaN   NaN
# 25                NaN   NaN
# 26                NaN   4.0
# 27                NaN   NaN
# 28                NaN   NaN
# 29                NaN   NaN
# ...               ...   ...
# 2197              NaN   NaN
# 2198              NaN   1.0
# 2199              NaN   1.0
# 2200              NaN   1.0
# 2201              NaN   2.0
# 2202              NaN   3.0
# 2203              NaN   NaN
# 2204              NaN   1.0
# 2205              NaN   NaN
# 2206              NaN   NaN
# 2207              NaN   NaN
# 2208              NaN   1.0
# 2209              NaN   1.0
# 2210              NaN   1.0
# 2211              NaN   1.0
# 2212              NaN   NaN
# 2213              NaN   NaN
# 2214              NaN   1.0
# 2215              NaN   3.0
# 2216              NaN   1.0
# 2217              NaN   NaN
# 2218              NaN   1.0
# 2219              NaN   NaN
# 2220              NaN   NaN
# 2221              NaN   3.0
# 2222              NaN   1.0
# 2223              NaN   1.0
# 2224              NaN   2.0
# 2225              NaN   1.0
# 2226              NaN   1.0
#
# [2227 rows x 12 columns]

# %%
charevent_txt_distanct.to_csv('charevent_txt_distanct.csv', index = False)

# %%
def get_variable_mapping(mimic_mapping_filename):
    # Read in the second level mapping of the itemids
    var_map = pd.read_csv(mimic_mapping_filename, index_col=None)
    var_map = var_map.ix[(var_map['LEVEL2'] != '') & (var_map['COUNT']>0)]
    var_map = var_map.ix[(var_map['STATUS'] == 'ready')]
    var_map['ITEMID'] = var_map['ITEMID'].astype(int)

    return var_map

# %%
mimic_mapping_filename = './resources/itemid_to_variable_map.csv'
var_map = get_variable_mapping(mimic_mapping_filename)
# Out:
# D:\software\Anaconda3\envs\mimiciv\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# D:\software\Anaconda3\envs\mimiciv\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """

# %%
var_map
# Out:
#                                    LEVEL2                              LEVEL1  \
# 0                Alanine aminotransferase            Alanine aminotransferase
# 1                Alanine aminotransferase            Alanine aminotransferase
# 2                Alanine aminotransferase            Alanine aminotransferase
# 3                                 Albumin                             Albumin
# 4                                 Albumin                             Albumin
# 5                                 Albumin                             Albumin
# 6                                 Albumin                             Albumin
# 8                         Albumin ascites                   Albumin (ascites)
# 10                        Albumin pleural                   Albumin (pleural)
# 11                          Albumin urine                     Albumin (urine)
# 12                     Alkaline phosphate                  Alkaline phosphate
# 13                     Alkaline phosphate                  Alkaline phosphate
# 14                     Alkaline phosphate                  Alkaline phosphate
# 16                              Anion gap                           Anion gap
# 17                              Anion gap                           Anion gap
# 19              Asparate aminotransferase           Asparate aminotransferase
# 20              Asparate aminotransferase           Asparate aminotransferase
# 21              Asparate aminotransferase           Asparate aminotransferase
# 22                              Basophils                           Basophils
# 28                            Bicarbonate                         Bicarbonate
# 29                            Bicarbonate                 Bicarbonate (serum)
# 30                            Bicarbonate           Bicarbonate (whole blood)
# 33                              Bilirubin              Bilirubin (conjugated)
# 34                              Bilirubin              Bilirubin (conjugated)
# 35                              Bilirubin              Bilirubin (conjugated)
# 39                              Bilirubin                   Bilirubin (total)
# 40                              Bilirubin                   Bilirubin (total)
# 41                              Bilirubin                   Bilirubin (total)
# 42                              Bilirubin                   Bilirubin (total)
# 43                              Bilirubin            Bilirubin (unconjugated)
# ...                                   ...                                 ...
# 392          Systemic Vascular Resistance        Systemic Vascular Resistance
# 393         Cardiac Output Thermodilution       Cardiac Output Thermodilution
# 394                   Cardiac Output fick                 Cardiac Output fick
# 395    Pulmonary Capillary Wedge Pressure  Pulmonary Capillary Wedge Pressure
# 397                    Post Void Residual                  Post Void Residual
# 401                           Phosphorous                         Phosphorous
# 402                           Phosphorous                         Phosphorous
# 403                           Phosphorous                         Phosphorous
# 404                            Fibrinogen                          Fibrinogen
# 405                            Fibrinogen                          Fibrinogen
# 406                            Fibrinogen                          Fibrinogen
# 408                            Fibrinogen                          Fibrinogen
# 410                         Total Protein                       Total Protein
# 411                         Total Protein                       Total Protein
# 414                   Total Protein Urine                 Total Protein Urine
# 417                           Venous PvO2                         Venous PvO2
# 418                      Plateau Pressure                    Plateau Pressure
# 419                      Plateau Pressure                    Plateau Pressure
# 420                 Tidal Volume Observed               Tidal Volume Observed
# 421                 Tidal Volume Observed               Tidal Volume Observed
# 423                 Tidal Volume Observed               Tidal Volume Observed
# 424                      Tidal Volume Set                    Tidal Volume Set
# 425                      Tidal Volume Set                    Tidal Volume Set
# 426              Tidal Volume Spontaneous            Tidal Volume Spontaneous
# 427              Tidal Volume Spontaneous            Tidal Volume Spontaneous
# 13235                        Urine output                        Urine output
# 13237                        Urine output                        Urine output
# 13238                        Urine output                        Urine output
# 13241                        Urine output                Urine output (foley)
# 13249                        Urine output                        Urine output
#
#                       ALTERNATIVE STATUS STATUS NOTE  ITEMID  \
# 0                             ALT  ready         NaN   50861
# 1                             ALT  ready         NaN     769
# 2                             ALT  ready         NaN  220644
# 3                             NaN  ready         NaN   50862
# 4                             NaN  ready         NaN     772
# 5                             NaN  ready         NaN    1521
# 6                             NaN  ready         NaN  227456
# 8                             NaN  ready         NaN   50835
# 10                            NaN  ready         NaN   51046
# 11                            NaN  ready         NaN   51069
# 12                            ALP  ready         NaN   50863
# 13                            ALP  ready         NaN     773
# 14                            ALP  ready         NaN  225612
# 16                            NaN  ready         NaN   50868
# 17                            NaN  ready         NaN  227073
# 19                            AST  ready         NaN   50878
# 20                            AST  ready         NaN     770
# 21                            AST  ready         NaN  220587
# 22                            NaN  ready         NaN   51146
# 28                           HCO3  ready         NaN   50882
# 29                   HCO3 (serum)  ready         NaN  227443
# 30             HCO3 (whole blood)  ready         NaN   50803
# 33               Direct bilirubin  ready         NaN   50883
# 34               Direct bilirubin  ready         NaN     803
# 35               Direct bilirubin  ready         NaN  225651
# 39                Total bilirubin  ready         NaN   50885
# 40                Total bilirubin  ready         NaN    1538
# 41                Total bilirubin  ready         NaN     848
# 42                Total bilirubin  ready         NaN  225690
# 43                            NaN  ready         NaN   50884
# ...                           ...    ...         ...     ...
# 392                           NaN  ready         NaN     626
# 393                           NaN  ready         NaN      90
# 394                           NaN  ready         NaN      89
# 395                           NaN  ready         NaN     504
# 397                           NaN  ready         NaN     512
# 401                           NaN  ready         NaN     827
# 402                   Phosphorous  ready         NaN  225677
# 403                           NaN  ready         NaN    1534
# 404                           NaN  ready         NaN     806
# 405                           NaN  ready         NaN    1528
# 406                    Fibrinogen  ready         NaN  227468
# 408                           NaN  ready         NaN   51214
# 410                           NaN  ready         NaN     849
# 411                           NaN  ready         NaN    1539
# 414                           NaN  ready         NaN   51102
# 417                           NaN  ready         NaN     859
# 418                           NaN  ready         NaN     543
# 419              Plateau Pressure  ready         NaN  224696
# 420                           NaN  ready         NaN     682
# 421                           NaN  ready         NaN   50826
# 423       Tidal Volume (observed)  ready         NaN  224685
# 424                           NaN  ready         NaN     683
# 425            Tidal Volume (set)  ready         NaN  224684
# 426                           NaN  ready         NaN     684
# 427    Tidal Volume (spontaneous)  ready         NaN  224686
# 13235                         NaN  ready         NaN   40473
# 13237                         NaN  ready         NaN   40715
# 13238                         NaN  ready         NaN   43175
# 13241                         NaN  ready         NaN  226559
# 13249                    OR Urine  ready         NaN  226627
#
#                                MIMIC LABEL UNITNAME       LINKSTO      COUNT  \
# 0           ALANINE AMINOTRANSFERASE (ALT)      NaN     labevents   219475.0
# 1                                      ALT      NaN   chartevents    41594.0
# 2                                      ALT     None   chartevents    37625.0
# 3                                  ALBUMIN      NaN     labevents   146697.0
# 4                           Albumin (>3.2)      NaN   chartevents    31022.0
# 5                                  Albumin      NaN   chartevents    24454.0
# 6                                  Albumin     None   chartevents    22945.0
# 8                         ALBUMIN, ASCITES      NaN     labevents     1592.0
# 10                        ALBUMIN, PLEURAL      NaN     labevents     1175.0
# 11                          ALBUMIN, URINE      NaN     labevents     2381.0
# 12                    ALKALINE PHOSPHATASE      NaN     labevents   207860.0
# 13                          Alk. Phosphate      NaN   chartevents    40637.0
# 14                      Alkaline Phosphate     None   chartevents    36836.0
# 16                               ANION GAP      NaN     labevents   769895.0
# 17                               Anion gap     None   chartevents   150220.0
# 19         ASPARATE AMINOTRANSFERASE (AST)      NaN     labevents   219465.0
# 20                                     AST      NaN   chartevents    41447.0
# 21                                     AST     None   chartevents    37598.0
# 22                               BASOPHILS      NaN     labevents   172142.0
# 28                             BICARBONATE      NaN     labevents   780733.0
# 29                            HCO3 (serum)     None   chartevents   152671.0
# 30     CALCULATED BICARBONATE, WHOLE BLOOD      NaN     labevents     9246.0
# 33                       BILIRUBIN, DIRECT      NaN     labevents    45205.0
# 34                     Direct Bili (0-0.3)      NaN   chartevents    22646.0
# 35                        Direct Bilirubin     None   chartevents     3341.0
# 39                        BILIRUBIN, TOTAL      NaN     labevents   238277.0
# 40                              Total Bili      NaN   chartevents    51334.0
# 41                      Total Bili (0-1.5)      NaN   chartevents    40239.0
# 42                         Total Bilirubin     None   chartevents    37961.0
# 43                     BILIRUBIN, INDIRECT      NaN     labevents    44385.0
# ...                                    ...      ...           ...        ...
# 392                                    SVR      NaN   chartevents   202999.0
# 393                   C.O.(thermodilution)      NaN   chartevents   176856.0
# 394                            C.O. (fick)      NaN   chartevents    39939.0
# 395                                   PCWP      NaN   chartevents    26562.0
# 397                                    PVR      NaN   chartevents    14931.0
# 401                   Phosphorous(2.7-4.5)      NaN   chartevents   163820.0
# 402                            Phosphorous     None   chartevents   135440.0
# 403                            Phosphorous      NaN   chartevents   134714.0
# 404                   Fibrinogen (150-400)      NaN   chartevents    18725.0
# 405                             Fibrinogen      NaN   chartevents    15727.0
# 406                             Fibrinogen     None   chartevents    14339.0
# 408                 FIBRINOGEN, FUNCTIONAL      NaN     labevents    45935.0
# 410                   Total Protein(6.5-8)      NaN   chartevents     1088.0
# 411                          Total Protein      NaN   chartevents      807.0
# 414                   TOTAL PROTEIN, URINE      NaN     labevents     9080.0
# 417                            Venous PvO2      NaN   chartevents    10512.0
# 418                       Plateau Pressure      NaN   chartevents   175482.0
# 419                       Plateau Pressure    cmH2O   chartevents    75376.0
# 420                   Tidal Volume (Obser)      NaN   chartevents   249517.0
# 421                           TIDAL VOLUME      NaN     labevents    83808.0
# 423                Tidal Volume (observed)       mL   chartevents   458370.0
# 424                     Tidal Volume (Set)      NaN   chartevents   230723.0
# 425                     Tidal Volume (set)       mL   chartevents   209506.0
# 426                   Tidal Volume (Spont)      NaN   chartevents   197149.0
# 427             Tidal Volume (spontaneous)       mL   chartevents   277015.0
# 13235                Urine Out IleoConduit      NaN  outputevents     4813.0
# 13237                 Urine Out Suprapubic      NaN  outputevents     6913.0
# 13238                              Urine .      NaN  outputevents   108982.0
# 13241                                Foley       mL  outputevents  1186717.0
# 13249                             OR Urine       mL  outputevents     5928.0
#
#                  CATEGORY  CONCEPTID    FLUID LOINC_CODE    DBSOURCE  \
# 0               CHEMISTRY        NaN    BLOOD                    NaN
# 1                 Enzymes        NaN      NaN        NaN     carevue
# 2                    Labs        NaN      NaN        NaN  metavision
# 3               CHEMISTRY        NaN    BLOOD     1751-7         NaN
# 4               Chemistry        NaN      NaN        NaN     carevue
# 5               Chemistry        NaN      NaN        NaN     carevue
# 6                    Labs        NaN      NaN        NaN  metavision
# 8               CHEMISTRY        NaN  ASCITES     1749-1         NaN
# 10              CHEMISTRY        NaN  PLEURAL     1748-3         NaN
# 11              CHEMISTRY        NaN    URINE     1754-1         NaN
# 12              CHEMISTRY        NaN    BLOOD     6768-6         NaN
# 13                Enzymes        NaN      NaN        NaN     carevue
# 14                   Labs        NaN      NaN        NaN  metavision
# 16              CHEMISTRY        NaN    BLOOD     1863-0         NaN
# 17                   Labs        NaN      NaN        NaN  metavision
# 19              CHEMISTRY        NaN    BLOOD     1920-8         NaN
# 20                Enzymes        NaN      NaN        NaN     carevue
# 21                   Labs        NaN      NaN        NaN  metavision
# 22             HEMATOLOGY        NaN    BLOOD      704-7         NaN
# 28              CHEMISTRY        NaN    BLOOD     1963-8         NaN
# 29                   Labs        NaN      NaN        NaN  metavision
# 30              BLOOD GAS        NaN    BLOOD     1959-6         NaN
# 33              CHEMISTRY        NaN    BLOOD     1968-7         NaN
# 34              Chemistry        NaN      NaN        NaN     carevue
# 35                   Labs        NaN      NaN        NaN  metavision
# 39              CHEMISTRY        NaN    BLOOD     1975-2         NaN
# 40              Chemistry        NaN      NaN        NaN     carevue
# 41              Chemistry        NaN      NaN        NaN     carevue
# 42                   Labs        NaN      NaN        NaN  metavision
# 43              CHEMISTRY        NaN    BLOOD     1971-1         NaN
# ...                   ...        ...      ...        ...         ...
# 392                   NaN        NaN      NaN        NaN     carevue
# 393                   NaN        NaN      NaN        NaN     carevue
# 394                   NaN        NaN      NaN        NaN     carevue
# 395                   NaN        NaN      NaN        NaN     carevue
# 397                   NaN        NaN      NaN        NaN     carevue
# 401             Chemistry        NaN      NaN        NaN     carevue
# 402                  Labs        NaN      NaN        NaN  metavision
# 403             Chemistry        NaN      NaN        NaN     carevue
# 404                 Coags        NaN      NaN        NaN     carevue
# 405                 Coags        NaN      NaN        NaN     carevue
# 406                  Labs        NaN      NaN        NaN  metavision
# 408            HEMATOLOGY        NaN    BLOOD     3255-7         NaN
# 410             Chemistry        NaN      NaN        NaN     carevue
# 411             Chemistry        NaN      NaN        NaN     carevue
# 414             CHEMISTRY        NaN    URINE     2887-8         NaN
# 417    Mixed Venous Gases        NaN      NaN        NaN     carevue
# 418                   NaN        NaN      NaN        NaN     carevue
# 419           Respiratory        NaN      NaN        NaN  metavision
# 420                   NaN        NaN      NaN        NaN     carevue
# 421             BLOOD GAS        NaN    BLOOD    20112-9         NaN
# 423           Respiratory        NaN      NaN        NaN  metavision
# 424                   NaN        NaN      NaN        NaN     carevue
# 425           Respiratory        NaN      NaN        NaN  metavision
# 426                   NaN        NaN      NaN        NaN     carevue
# 427           Respiratory        NaN      NaN        NaN  metavision
# 13235                 NaN        NaN      NaN        NaN     carevue
# 13237                 NaN        NaN      NaN        NaN     carevue
# 13238                 NaN        NaN      NaN        NaN     carevue
# 13241              Output        NaN      NaN        NaN  metavision
# 13249              Output        NaN      NaN        NaN  metavision
#
#        Unnamed: 15        PARAM_TYPE  NOTE
# 0              NaN               NaN   NaN
# 1              NaN               NaN   NaN
# 2              NaN           Numeric   NaN
# 3              NaN               NaN   NaN
# 4              NaN               NaN   NaN
# 5              NaN               NaN   NaN
# 6              NaN  Numeric with tag   NaN
# 8              NaN               NaN   NaN
# 10             NaN               NaN   NaN
# 11             NaN               NaN   NaN
# 12             NaN               NaN   NaN
# 13             NaN               NaN   NaN
# 14             NaN           Numeric   NaN
# 16             NaN               NaN   NaN
# 17             NaN           Numeric   NaN
# 19             NaN               NaN   NaN
# 20             NaN               NaN   NaN
# 21             NaN           Numeric   NaN
# 22             NaN               NaN   NaN
# 28             NaN               NaN   NaN
# 29             NaN  Numeric with tag   NaN
# 30             NaN               NaN   NaN
# 33             NaN               NaN   NaN
# 34             NaN               NaN   NaN
# 35             NaN           Numeric   NaN
# 39             NaN               NaN   NaN
# 40             NaN               NaN   NaN
# 41             NaN               NaN   NaN
# 42             NaN           Numeric   NaN
# 43             NaN               NaN   NaN
# ...            ...               ...   ...
# 392            NaN               NaN   NaN
# 393            NaN               NaN   NaN
# 394            NaN               NaN   NaN
# 395            NaN               NaN   NaN
# 397            NaN               NaN   NaN
# 401            NaN               NaN   NaN
# 402            NaN           Numeric   NaN
# 403            NaN               NaN   NaN
# 404            NaN               NaN   NaN
# 405            NaN               NaN   NaN
# 406            NaN  Numeric with tag   NaN
# 408            NaN               NaN   NaN
# 410            NaN               NaN   NaN
# 411            NaN               NaN   NaN
# 414            NaN               NaN   NaN
# 417            NaN               NaN   NaN
# 418            NaN               NaN   NaN
# 419            NaN           Numeric   NaN
# 420            NaN               NaN   NaN
# 421            NaN               NaN   NaN
# 423            NaN           Numeric   NaN
# 424            NaN               NaN   NaN
# 425            NaN           Numeric   NaN
# 426            NaN               NaN   NaN
# 427            NaN           Numeric   NaN
# 13235          NaN               NaN   NaN
# 13237          NaN               NaN   NaN
# 13238          NaN               NaN   NaN
# 13241          NaN               NaN   NaN
# 13249          NaN               NaN   NaN
#
# [313 rows x 18 columns]

# %%
chartitems = var_map.loc[var_map['LINKSTO'] == 'chartevents'].ITEMID

# %%
chartitems = chartitems.to_list()

# %%
charevent_txt_distanct['is_in_extract'] = charevent_txt_distanct['itemid'].apply(lambda x:1 if x in chartitems else 0)

# %%
charevent_txt_distanct.to_csv('charevent.csv', index = False)

# %%
ham_id_count = pd.read_sql_query('select count(distinct hadm_id) from mimiciv_derived.icustay_detail',querier.connection ).iloc[0][0]

# %%
ham_id_count
# Out:
# 66239

# %%
query = '''
with t1 as (select itemid, labevents.hadm_id from mimiciv_hosp.labevents inner join mimiciv_derived.icustay_detail on icustay_detail.hadm_id = labevents.hadm_id
where labevents.charttime between icustay_detail.icu_intime and icustay_detail.icu_outtime
group by itemid, labevents.hadm_id)
, t2 as (select itemid, count(*) as count from t1 group by itemid order by count desc)
select  t2.count, d_labitems.* from t2 inner join mimiciv_hosp.d_labitems on t2.itemid = d_labitems.itemid order by count desc;
'''
labevent_with_txt = pd.read_sql_query(query,querier.connection )

# %%
labevent_with_txt.insert(1,'percentage', labevent_with_txt['count'] / ham_id_count)

# %%
labevent_with_txt
# Out:
#      count  percentage  itemid                        label             fluid  \
# 0    64206    0.969308   50971                    Potassium             Blood
# 1    64206    0.969308   50983                       Sodium             Blood
# 2    64204    0.969278   50902                     Chloride             Blood
# 3    64180    0.968916   50912                   Creatinine             Blood
# 4    64177    0.968870   51006                Urea Nitrogen             Blood
# 5    64170    0.968765   50882                  Bicarbonate             Blood
# 6    64141    0.968327   50868                    Anion Gap             Blood
# 7    64096    0.967647   51221                   Hematocrit             Blood
# 8    64081    0.967421   50931                      Glucose             Blood
# 9    63955    0.965519   51265               Platelet Count             Blood
# 10   63935    0.965217   51301            White Blood Cells             Blood
# 11   63934    0.965202   51222                   Hemoglobin             Blood
# 12   63925    0.965066   51250                          MCV             Blood
# 13   63925    0.965066   51249                         MCHC             Blood
# 14   63925    0.965066   51248                          MCH             Blood
# 15   63925    0.965066   51279              Red Blood Cells             Blood
# 16   63924    0.965051   51277                          RDW             Blood
# 17   63046    0.951796   50960                    Magnesium             Blood
# 18   61643    0.930615   50970                    Phosphate             Blood
# 19   61594    0.929875   50893               Calcium, Total             Blood
# 20   56498    0.852942   51237                      INR(PT)             Blood
# 21   56498    0.852942   51274                           PT             Blood
# 22   56152    0.847718   51275                          PTT             Blood
# 23   41473    0.626112   52033                Specimen Type             Blood
# 24   40088    0.605202   50820                           pH             Blood
# 25   38813    0.585954   50813                      Lactate             Blood
# 26   38496    0.581168   50802                  Base Excess             Blood
# 27   38492    0.581108   50821                          pO2             Blood
# 28   38490    0.581078   50804         Calculated Total CO2             Blood
# 29   38489    0.581063   50818                         pCO2             Blood
# ..     ...         ...     ...                          ...               ...
# 791      1    0.000015   51468   Calcium Carbonate Crystals             Urine
# 792      1    0.000015   51407                         CD38  Other Body Fluid
# 793      1    0.000015   50888         Blue Top Hold Frozen             Blood
# 794      1    0.000015   51153                        CD103             Blood
# 795      1    0.000015   51037        Magnesium, Body Fluid  Other Body Fluid
# 796      1    0.000015   51473            Cysteine Crystals             Urine
# 797      1    0.000015   51024   Total Protein, Joint Fluid       Joint Fluid
# 798      1    0.000015   51396                         CD16  Other Body Fluid
# 799      1    0.000015   51126                Promyelocytes           Ascites
# 800      1    0.000015   51113                       Blasts           Ascites
# 801      1    0.000015   51280               Reptilase Time             Blood
# 802      1    0.000015   51281       Reptilase Time Control             Blood
# 803      1    0.000015   51927               Albumin, Stool             Stool
# 804      1    0.000015   51504            Tyrosine Crystals             Urine
# 805      1    0.000015   51033                      FetalFN  Other Body Fluid
# 806      1    0.000015   52313              Voided Specimen       Joint Fluid
# 807      1    0.000015   51904                         PAN2  Other Body Fluid
# 808      1    0.000015   51031      Cholesterol, Body Fluid  Other Body Fluid
# 809      1    0.000015   51378               Metamyelocytes       Joint Fluid
# 810      1    0.000015   51899        Trichomonas vaginalis  Other Body Fluid
# 811      1    0.000015   51389                        CD103  Other Body Fluid
# 812      1    0.000015   51714      Reflex HIV Confirmation             Blood
# 813      1    0.000015   50962  N-Acetylprocainamide (NAPA)             Blood
# 814      1    0.000015   50972                 Procainamide             Blood
# 815      1    0.000015   51083               Ethanol, Urine             Urine
# 816      1    0.000015   51322                         CD38       Bone Marrow
# 817      1    0.000015   51496   Reducing Substances, Urine             Urine
# 818      1    0.000015   51414                         CD57  Other Body Fluid
# 819      1    0.000015   51050            Chloride, Pleural           Pleural
# 820      1    0.000015   51171                         CD22             Blood
#
#        category
# 0     Chemistry
# 1     Chemistry
# 2     Chemistry
# 3     Chemistry
# 4     Chemistry
# 5     Chemistry
# 6     Chemistry
# 7    Hematology
# 8     Chemistry
# 9    Hematology
# 10   Hematology
# 11   Hematology
# 12   Hematology
# 13   Hematology
# 14   Hematology
# 15   Hematology
# 16   Hematology
# 17    Chemistry
# 18    Chemistry
# 19    Chemistry
# 20   Hematology
# 21   Hematology
# 22   Hematology
# 23    Blood Gas
# 24    Blood Gas
# 25    Blood Gas
# 26    Blood Gas
# 27    Blood Gas
# 28    Blood Gas
# 29    Blood Gas
# ..          ...
# 791  Hematology
# 792  Hematology
# 793   Chemistry
# 794  Hematology
# 795   Chemistry
# 796  Hematology
# 797   Chemistry
# 798  Hematology
# 799  Hematology
# 800  Hematology
# 801  Hematology
# 802  Hematology
# 803   Chemistry
# 804  Hematology
# 805   Chemistry
# 806  Hematology
# 807   Chemistry
# 808   Chemistry
# 809  Hematology
# 810   Chemistry
# 811  Hematology
# 812   Chemistry
# 813   Chemistry
# 814   Chemistry
# 815   Chemistry
# 816  Hematology
# 817  Hematology
# 818  Hematology
# 819   Chemistry
# 820  Hematology
#
# [821 rows x 6 columns]

# %%
labitems_to_keep = var_map.loc[var_map['LINKSTO'] == 'labevents'].ITEMID

# %%
labevent_with_txt = labitems_to_keep.to_list()

# %%
labevent_with_txt['is_in_extract'] = labevent_with_txt['itemid'].apply(lambda x:1 if x in labitems_to_keep else 0)

# %%
labevent_with_txt
# Out:
#      count  percentage  itemid                        label             fluid  \
# 0    64206    0.969308   50971                    Potassium             Blood
# 1    64206    0.969308   50983                       Sodium             Blood
# 2    64204    0.969278   50902                     Chloride             Blood
# 3    64180    0.968916   50912                   Creatinine             Blood
# 4    64177    0.968870   51006                Urea Nitrogen             Blood
# 5    64170    0.968765   50882                  Bicarbonate             Blood
# 6    64141    0.968327   50868                    Anion Gap             Blood
# 7    64096    0.967647   51221                   Hematocrit             Blood
# 8    64081    0.967421   50931                      Glucose             Blood
# 9    63955    0.965519   51265               Platelet Count             Blood
# 10   63935    0.965217   51301            White Blood Cells             Blood
# 11   63934    0.965202   51222                   Hemoglobin             Blood
# 12   63925    0.965066   51250                          MCV             Blood
# 13   63925    0.965066   51249                         MCHC             Blood
# 14   63925    0.965066   51248                          MCH             Blood
# 15   63925    0.965066   51279              Red Blood Cells             Blood
# 16   63924    0.965051   51277                          RDW             Blood
# 17   63046    0.951796   50960                    Magnesium             Blood
# 18   61643    0.930615   50970                    Phosphate             Blood
# 19   61594    0.929875   50893               Calcium, Total             Blood
# 20   56498    0.852942   51237                      INR(PT)             Blood
# 21   56498    0.852942   51274                           PT             Blood
# 22   56152    0.847718   51275                          PTT             Blood
# 23   41473    0.626112   52033                Specimen Type             Blood
# 24   40088    0.605202   50820                           pH             Blood
# 25   38813    0.585954   50813                      Lactate             Blood
# 26   38496    0.581168   50802                  Base Excess             Blood
# 27   38492    0.581108   50821                          pO2             Blood
# 28   38490    0.581078   50804         Calculated Total CO2             Blood
# 29   38489    0.581063   50818                         pCO2             Blood
# ..     ...         ...     ...                          ...               ...
# 791      1    0.000015   51468   Calcium Carbonate Crystals             Urine
# 792      1    0.000015   51407                         CD38  Other Body Fluid
# 793      1    0.000015   50888         Blue Top Hold Frozen             Blood
# 794      1    0.000015   51153                        CD103             Blood
# 795      1    0.000015   51037        Magnesium, Body Fluid  Other Body Fluid
# 796      1    0.000015   51473            Cysteine Crystals             Urine
# 797      1    0.000015   51024   Total Protein, Joint Fluid       Joint Fluid
# 798      1    0.000015   51396                         CD16  Other Body Fluid
# 799      1    0.000015   51126                Promyelocytes           Ascites
# 800      1    0.000015   51113                       Blasts           Ascites
# 801      1    0.000015   51280               Reptilase Time             Blood
# 802      1    0.000015   51281       Reptilase Time Control             Blood
# 803      1    0.000015   51927               Albumin, Stool             Stool
# 804      1    0.000015   51504            Tyrosine Crystals             Urine
# 805      1    0.000015   51033                      FetalFN  Other Body Fluid
# 806      1    0.000015   52313              Voided Specimen       Joint Fluid
# 807      1    0.000015   51904                         PAN2  Other Body Fluid
# 808      1    0.000015   51031      Cholesterol, Body Fluid  Other Body Fluid
# 809      1    0.000015   51378               Metamyelocytes       Joint Fluid
# 810      1    0.000015   51899        Trichomonas vaginalis  Other Body Fluid
# 811      1    0.000015   51389                        CD103  Other Body Fluid
# 812      1    0.000015   51714      Reflex HIV Confirmation             Blood
# 813      1    0.000015   50962  N-Acetylprocainamide (NAPA)             Blood
# 814      1    0.000015   50972                 Procainamide             Blood
# 815      1    0.000015   51083               Ethanol, Urine             Urine
# 816      1    0.000015   51322                         CD38       Bone Marrow
# 817      1    0.000015   51496   Reducing Substances, Urine             Urine
# 818      1    0.000015   51414                         CD57  Other Body Fluid
# 819      1    0.000015   51050            Chloride, Pleural           Pleural
# 820      1    0.000015   51171                         CD22             Blood
#
#        category  is_in_extract
# 0     Chemistry              1
# 1     Chemistry              1
# 2     Chemistry              1
# 3     Chemistry              1
# 4     Chemistry              1
# 5     Chemistry              1
# 6     Chemistry              1
# 7    Hematology              1
# 8     Chemistry              1
# 9    Hematology              1
# 10   Hematology              1
# 11   Hematology              1
# 12   Hematology              1
# 13   Hematology              1
# 14   Hematology              1
# 15   Hematology              1
# 16   Hematology              0
# 17    Chemistry              1
# 18    Chemistry              1
# 19    Chemistry              1
# 20   Hematology              1
# 21   Hematology              1
# 22   Hematology              1
# 23    Blood Gas              0
# 24    Blood Gas              1
# 25    Blood Gas              1
# 26    Blood Gas              0
# 27    Blood Gas              0
# 28    Blood Gas              1
# 29    Blood Gas              1
# ..          ...            ...
# 791  Hematology              0
# 792  Hematology              0
# 793   Chemistry              0
# 794  Hematology              0
# 795   Chemistry              0
# 796  Hematology              0
# 797   Chemistry              0
# 798  Hematology              0
# 799  Hematology              0
# 800  Hematology              0
# 801  Hematology              0
# 802  Hematology              0
# 803   Chemistry              0
# 804  Hematology              0
# 805   Chemistry              0
# 806  Hematology              0
# 807   Chemistry              0
# 808   Chemistry              0
# 809  Hematology              0
# 810   Chemistry              0
# 811  Hematology              0
# 812   Chemistry              0
# 813   Chemistry              0
# 814   Chemistry              0
# 815   Chemistry              0
# 816  Hematology              0
# 817  Hematology              0
# 818  Hematology              0
# 819   Chemistry              0
# 820  Hematology              0
#
# [821 rows x 7 columns]

# %%
labevent_with_txt.to_csv('labevent.csv')

# %% [markdown]
# # save data to csv

# %%
query = '''
with t as (select * from mimiciv_derived.chartevent_t1 limit 10000)
select subject_id, hadm_id,stay_id, t.itemid, d_items.label, charttime,lag_time,t.value, t.valuenum,t.valueuom,
       case
        when t.lag_time is not null
        then mimiciv_derived.datetime_diff(t.charttime, t.lag_time, 'SECOND')
        else 0
        end as offset
from t inner join mimiciv_icu.d_items on t.itemid = d_items.itemid
'''
patient_X = pd.read_sql_query(query,querier.connection )

# %%
patient_X
# Out:
#       subject_id   hadm_id   stay_id  itemid  \
# 0       15904173  23836605  30001947  229027
# 1       15904173  23836605  30001947  229027
# 2       15904173  23836605  30001947  229032
# 3       15904173  23836605  30001947  229032
# 4       15904173  23836605  30001947  229032
# 5       15904173  23836605  30001947  229032
# 6       15904173  23836605  30001947  229032
# 7       15904173  23836605  30001947  229032
# 8       15904173  23836605  30001947  229032
# 9       15904173  23836605  30001947  229032
# 10      15904173  23836605  30001947  229032
# 11      15904173  23836605  30001947  229098
# 12      15904173  23836605  30001947  229099
# 13      15904173  23836605  30001947  229099
# 14      15904173  23836605  30001947  229099
# 15      15904173  23836605  30001947  229099
# 16      15904173  23836605  30001947  229099
# 17      15904173  23836605  30001947  229100
# 18      15904173  23836605  30001947  229100
# 19      15904173  23836605  30001947  229100
# 20      15904173  23836605  30001947  229101
# 21      15904173  23836605  30001947  229101
# 22      15904173  23836605  30001947  229101
# 23      15904173  23836605  30001947  229106
# 24      15904173  23836605  30001947  229107
# 25      15904173  23836605  30001947  229107
# 26      15904173  23836605  30001947  229107
# 27      17921898  28841024  30002415  220001
# 28      17921898  28841024  30002415  220001
# 29      17921898  28841024  30002415  220045
# ...          ...       ...       ...     ...
# 9970    10682002  20035892  30003087  224073
# 9971    10682002  20035892  30003087  224073
# 9972    10682002  20035892  30003087  224073
# 9973    10682002  20035892  30003087  224073
# 9974    10682002  20035892  30003087  224073
# 9975    10682002  20035892  30003087  224073
# 9976    10682002  20035892  30003087  224073
# 9977    10682002  20035892  30003087  224073
# 9978    10682002  20035892  30003087  224073
# 9979    10682002  20035892  30003087  224073
# 9980    10682002  20035892  30003087  224073
# 9981    10682002  20035892  30003087  224073
# 9982    10682002  20035892  30003087  224073
# 9983    10682002  20035892  30003087  224073
# 9984    10682002  20035892  30003087  224073
# 9985    10682002  20035892  30003087  224076
# 9986    10682002  20035892  30003087  224076
# 9987    10682002  20035892  30003087  224076
# 9988    10682002  20035892  30003087  224076
# 9989    10682002  20035892  30003087  224076
# 9990    10682002  20035892  30003087  224076
# 9991    10682002  20035892  30003087  224076
# 9992    10682002  20035892  30003087  224077
# 9993    10682002  20035892  30003087  224077
# 9994    10682002  20035892  30003087  224077
# 9995    10682002  20035892  30003087  224077
# 9996    10682002  20035892  30003087  224077
# 9997    10682002  20035892  30003087  224077
# 9998    10682002  20035892  30003087  224079
# 9999    10682002  20035892  30003087  224079
#
#                                                  label           charttime  \
# 0                                       Constitutional 2162-12-26 22:27:00
# 1                                       Constitutional 2162-12-27 02:26:00
# 2                                                HEENT 2162-12-26 22:27:00
# 3                                                HEENT 2162-12-26 22:27:00
# 4                                                HEENT 2162-12-26 22:27:00
# 4          NaN     None      0.0
# 5          NaN     None      0.0
# 6          NaN     None      0.0
# 7          NaN     None  14340.0
# 8          NaN     None      0.0
# 9          NaN     None      0.0
# 10         NaN     None      0.0
# 11         NaN     None      0.0
# 12         NaN     None      0.0
# 13         NaN     None  34980.0
# 14         NaN     None    120.0
# 15         NaN     None  25200.0
# 16         NaN     None  41460.0
# 17         NaN     None      0.0
# 18         NaN     None  25200.0
# 19         NaN     None  41460.0
# 20         NaN     None      0.0
# 21         NaN     None  25200.0
# 22         NaN     None  41460.0
# 23         NaN     None      0.0
# 24         NaN     None      0.0
# 25         NaN     None  25200.0
# 26         NaN     None  41460.0
# 27         NaN     None      0.0
# 28         NaN     None      0.0
# 29        80.0      bpm      0.0
# ...        ...      ...      ...
# 9970       NaN     None      0.0
# 9971       NaN     None      0.0
# 9972       NaN     None      0.0
# 9973       NaN     None  93240.0
# 9974       NaN     None      0.0
# 9975       NaN     None      0.0
# 9976       NaN     None      0.0
# 9977       NaN     None  72000.0
# 9978       NaN     None      0.0
# 9979       NaN     None  93240.0
# 9980       NaN     None      0.0
# 9981       NaN     None  83280.0
# 9982       NaN     None      0.0
# 9983       NaN     None      0.0
# 9984       NaN     None  39480.0
# 9985       NaN     None      0.0
# 9986       NaN     None      0.0
# 9987       NaN     None  93240.0
# 9988       NaN     None  72000.0
# 9989       NaN     None  93240.0
# 9990       NaN     None  83280.0
# 9991       NaN     None  39480.0
# 9992       NaN     None      0.0
# 9993       NaN     None  93240.0
# 9994       NaN     None  72000.0
# 9995       NaN     None  93240.0
# 9996       NaN     None  83280.0
# 9997       NaN     None  39480.0
# 9998       NaN     None      0.0
# 9999       NaN     None  93240.0
#
# [10000 rows x 11 columns]

# %%
patient_X.groupby(['subject_id','hadm_id','stay_id','itemid']).apply(lambda x: x.sort_values('charttime', ascending=False))
# Out:
#                                           subject_id   hadm_id   stay_id  \
# subject_id hadm_id  stay_id  itemid
# 10208468   25796414 30002925 220001 7454    10208468  25796414  30002925
#                                     7455    10208468  25796414  30002925
#                              220045 7474    10208468  25796414  30002925
#                                     7473    10208468  25796414  30002925
#                                     7472    10208468  25796414  30002925
#                                     7471    10208468  25796414  30002925
#                                     7470    10208468  25796414  30002925
#                                     7469    10208468  25796414  30002925
#                                     7468    10208468  25796414  30002925
#                                     7467    10208468  25796414  30002925
#                                     7466    10208468  25796414  30002925
#                                     7465    10208468  25796414  30002925
#                                     7464    10208468  25796414  30002925
#                                     7463    10208468  25796414  30002925
#                                     7462    10208468  25796414  30002925
#                                     7461    10208468  25796414  30002925
#                                     7460    10208468  25796414  30002925
#                                     7459    10208468  25796414  30002925
#                                     7458    10208468  25796414  30002925
#                                     7457    10208468  25796414  30002925
#                                     7456    10208468  25796414  30002925
#                              220046 7475    10208468  25796414  30002925
#                              220047 7476    10208468  25796414  30002925
#                              220048 7494    10208468  25796414  30002925
#                                     7493    10208468  25796414  30002925
#                                     7492    10208468  25796414  30002925
#                                     7491    10208468  25796414  30002925
#                                     7490    10208468  25796414  30002925
# subject_id hadm_id  stay_id  itemid
# 10208468   25796414 30002925 220001 7454       NaN     None      0.0
#                                     7455       NaN     None      0.0
#                              220045 7474      78.0      bpm   3600.0
#                                     7473      82.0      bpm   3600.0
#                                     7472      82.0      bpm   3600.0
#                                     7471      81.0      bpm   3600.0
#                                     7470      73.0      bpm    360.0
#                                     7469      79.0      bpm   6840.0
#                                     7468      66.0      bpm   3600.0
#                                     7467      65.0      bpm   3600.0
#                                     7466      71.0      bpm   3600.0
#                                     7465      68.0      bpm   3600.0
#                                     7464      72.0      bpm   3600.0
#                                     7463      69.0      bpm   3600.0
#                                     7462      67.0      bpm   3600.0
#                                     7461      65.0      bpm   3600.0
#                                     7460      67.0      bpm   3600.0
#                                     7459      68.0      bpm   3600.0
#                                     7458      73.0      bpm    300.0
#                                     7457      73.0      bpm    780.0
#                                     7456      70.0      bpm      0.0
#                              220046 7475     130.0      bpm      0.0
#                              220047 7476      50.0      bpm      0.0
#                              220048 7494       NaN     None   3600.0
#                                     7493       NaN     None   3600.0
#                                     7492       NaN     None   3600.0
#                                     7491       NaN     None   3600.0
#                                     7490       NaN     None   3600.0
#                                     7489       NaN     None   3600.0
#                                     7488       NaN     None   3600.0
# ...                                            ...      ...      ...
# 17938576   20818145 30002498 228947 2592       NaN     None      0.0
#                                     2591       NaN     None      0.0
#                                     2600       NaN     None      0.0
#                                     2585       NaN     None      0.0
#                                     2581       NaN     None      0.0
#                                     2582       NaN     None      0.0
#                                     2583       NaN     None      0.0
#                                     2584       NaN     None      0.0
#                                     2580       NaN     None      0.0
#                                     2586       NaN     None      0.0
#                                     2587       NaN     None      0.0
#                                     2588       NaN     None      0.0
#                                     2589       NaN     None      0.0
#                                     2579       NaN     None      0.0
#                              229090 2626       NaN     None  27720.0
#                                     2625       NaN     None  33960.0
#                                     2624       NaN     None   6000.0
#                                     2623       NaN     None      0.0
#                              229091 2630       NaN     None  27720.0
#                                     2629       NaN     None  33960.0
#                                     2628       NaN     None   6000.0
#                                     2627       NaN     None      0.0
#                              229102 2634       NaN     None  27720.0
#                                     2633       NaN     None  33960.0
#                                     2632       NaN     None   6000.0
#                                     2631       NaN     None      0.0
#                              229103 2638       NaN     None  27720.0
#                                     2637       NaN     None  33960.0
#                                     2636       NaN     None   6000.0
#                                     2635       NaN     None      0.0
#
# [10000 rows x 11 columns]

# %%
patient_X = patient_X.set_index('stay_id')

# %%
import os

# %%
for i in set(patient_X.index):
    tmp = patient_X.loc[i].groupby(['subject_id','hadm_id','stay_id','itemid']).apply(lambda x: x.sort_values('charttime', ascending=True))
    tmp_sub = tmp['subject_id'][0]
    tmp_hadm = tmp['hadm_id'][0]
    try:
        os.makedirs("D:/数据/香港实习/MIMICIV/MMICIV_Extract/MIMICIV_Extract/data/test/"+str(tmp_sub)+'/'+str(tmp_hadm))
    except Exception as e:
        print(e)
    tmp.to_csv('D:/数据/香港实习/MIMICIV/MMICIV_Extract/MIMICIV_Extract/data/test/'+str(tmp_sub)+'/'+str(tmp_hadm)+'/'+str(i)+'.csv', index=False)
